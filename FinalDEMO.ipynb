# %% [markdown]
# ## Это интерактивный notebook
# В гитхабе он выглядит статично, но если вы скачаете его, то будут доступны интерактивные элементы.
#
# Для интерактивной работы необходим модуль widgets.
#
# После подключения всех библиотек необходимо указать:
#
#     %matplotlib inline

# %%
from UtilityOptimization import *
# %matplotlib inline

# %% [markdown]
# ## Загрузка данных

# %%
ui = UI()
ui.ReadCsv('Appartments.csv')

#ui.ReadCsv('Appartments2.csv')
# Out:
#    Общая площадь  Цена  Площадь кухни
# 0             50   2.0              6
# 1             55   2.2              8
# 2             60   2.4             10
# 3             65   2.6             12
# 4             70   2.8             15

# %% [markdown]
# ## Выбор функций полезности и весов для каждого показателя

# %%
ui.SelectFunctions()

# %% [markdown]
# ## Просмотр оценок и рангов до редактирования

# %%
ui.ShowEstimates()
# Out:
#    Общая площадь      Цена  Площадь кухни    Оценки  Ранги
# 0       0.367879  0.731059       0.768525  0.598900      4
# 1       0.778801  0.645656       0.880797  0.781213      2
# 2       1.000000  0.549834       0.942676  0.867395      1
# 3       0.778801  0.450166       0.973403  0.764753      3
# 4       0.367879  0.354344       0.991837  0.582881      5

# %% [markdown]
# ## Выбор показателя для редактирования его фукнции полезности

# %%
ui.SelectFutureToChange()
# Out:
# Dropdown(description='Признак', layout=Layout(width='20%'), options=('Общая площадь', 'Цена', 'Площадь кухни')…

# %% [markdown]
# ## Изменение параметров

# %%
ui.ChangeParameters()
# Out:
# Функция полезности признака Цена
# interactive(children=(FloatSlider(value=1.0, description='beta', max=3.0, step=0.01), FloatSlider(value=2.7, d…

# %% [markdown]
# ## Просмотр вклада признака в оценку конкретного объекта

# %%
ui.ShowContributionDiagram('Цена', 0)

# %%
ui.ShowContributionDiagram('Цена', 4)
